# %% [markdown]
# #### injestion
# #### missing valuess
# - checking
# - methods of removing
# #### outliers
# - checking
# - removal

# %% [markdown]
# ### import the libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
### reading from the same folder
traffic_data = pd.read_csv("Traffic_Data.csv")
train_data = pd.read_csv("Train.csv")

## outisde the folder
diamonds_data = pd.read_excel("D:\\Github\\DS UCU Chapter\\Training-code-\\Diamonds\\PricingOfDiamonds.xlsx")
# method 2
diamonds_data = pd.read_excel("D:/Github/DS UCU Chapter/Training-code-/Diamonds/PricingOfDiamonds.xlsx")

# %% [markdown]
# a sample of our data

# %%
traffic_data.head(10)
# Out:
#            City        Vehicle Type      Weather Economic Condition  \
# 0  SolarisVille               Drone        Snowy             Stable
# 1      AquaCity          Flying Car  Solar Flare          Recession
# 2     Neuroburg  Autonomous Vehicle  Solar Flare          Recession
# 3     Ecoopolis               Drone        Clear            Booming
# 4      AquaCity  Autonomous Vehicle  Solar Flare             Stable
# 5     TechHaven  Autonomous Vehicle        Snowy          Recession
# 6     Ecoopolis  Autonomous Vehicle        Rainy          Recession
# 7     Ecoopolis  Autonomous Vehicle        Snowy             Stable
# 8   MetropolisX               Drone        Snowy          Recession
# 9  SolarisVille               Drone        Snowy            Booming
#
#   Day Of Week  Hour Of Day     Speed  Is Peak Hour  Random Event Occurred  \
# 0      Sunday           20   29.4268             0                      0
# ...

# %%
traffic_data.tail(10)
# Out:
#                  City        Vehicle Type                Weather  \
# 1219557      AquaCity  Autonomous Vehicle  Electromagnetic Storm
# 1219558   MetropolisX                 Car                  Snowy
# 1219559  SolarisVille               Drone                  Clear
# 1219560   MetropolisX  Autonomous Vehicle                  Rainy
# 1219561      AquaCity  Autonomous Vehicle            Solar Flare
# 1219562  SolarisVille  Autonomous Vehicle  Electromagnetic Storm
# 1219563   MetropolisX               Drone                  Snowy
# 1219564     Neuroburg  Autonomous Vehicle                  Snowy
# 1219565   MetropolisX  Autonomous Vehicle                  Clear
# 1219566     Ecoopolis               Drone  Electromagnetic Storm
#
#         Economic Condition Day Of Week  Hour Of Day    Speed  Is Peak Hour  \
# 1219557            Booming   Wednesday            4  94.2708             0
# 1219558             Stable   Wednesday           15  66.9125             0
# ...

# %%
traffic_data.dtypes
# Out:
# City                      object
# Vehicle Type              object
# Weather                   object
# Economic Condition        object
# Day Of Week               object
# Hour Of Day                int64
# Speed                    float64
# Is Peak Hour               int64
# Random Event Occurred      int64
# Energy Consumption       float64
# Traffic Density          float64
# dtype: object

# %% [markdown]
# ### Exploratory Data Anlaysis (EDA)

# %% [markdown]
# #### Missing values

# %%
df = {
    'one' : pd.Series([100,200, 300, 500, 600], index=['apples','oranges', 'mangoes', 'avocado', "pears"]),
    'two' : pd.Series([80,400, 100,70, 600], index=['apples','oranges', 'mangoes','grapes', 'avocado'])
}
dataframe = pd.DataFrame(df)
dataframe
# Out:
#            one    two
# apples   100.0   80.0
# avocado  500.0  600.0
# grapes     NaN   70.0
# mangoes  300.0  100.0
# oranges  200.0  400.0
# pears    600.0    NaN

# %%
dataframe.isnull().sum()
# Out:
# one    1
# two    1
# dtype: int64

# %% [markdown]
# ### Handling Missing data
# #### fillforward

# %%
dataframe = dataframe.fillna(method='ffill')
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_3192\3658286284.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe = dataframe.fillna(method='ffill')

# %%
dataframe.fillna(method='ffill', inplace=True)
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_3192\286803397.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe.fillna(method='ffill', inplace=True)

# %% [markdown]
# #### backforward

# %%
dataframe.fillna(method='backfill', inplace=True)
# Out:
# C:\Users\Hello\AppData\Local\Temp\ipykernel_3192\2619510544.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataframe.fillna(method='backfill', inplace=True)

# %%
dataframe
# Out:
#            one    two
# apples   100.0   80.0
# avocado  500.0  600.0
# grapes   500.0   70.0
# mangoes  300.0  100.0
# oranges  200.0  400.0
# pears    600.0  400.0

# %% [markdown]
# #### dropping
# axis { <br />
#   0 - index <br />
#   1 - columns <br />
# }

# %%
dataframe.dropna(axis=0)
# Out:
#            one    two
# apples   100.0   80.0
# avocado  500.0  600.0
# grapes   500.0   70.0
# mangoes  300.0  100.0
# oranges  200.0  400.0
# pears    600.0  400.0

# %%
dataframe.dropna(axis=1)
# Out:
#            one    two
# apples   100.0   80.0
# avocado  500.0  600.0
# grapes   500.0   70.0
# mangoes  300.0  100.0
# oranges  200.0  400.0
# pears    600.0  400.0

# %% [markdown]
# #### interporation

# %%
dataframe
# Out:
#            one    two
# apples   100.0   80.0
# avocado  500.0  600.0
# grapes   500.0   70.0
# mangoes  300.0  100.0
# oranges  200.0  400.0
# pears    600.0  400.0

# %%
dataframe.interpolate()
# Out:
#            one    two
# apples   100.0   80.0
# avocado  500.0  600.0
# grapes   500.0   70.0
# mangoes  300.0  100.0
# oranges  200.0  400.0
# pears    600.0  400.0

# %% [markdown]
# ### Imputataion

# %%
train_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               1
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               5
# dtype: int64

# %%
train_data.dtypes
# Out:
# Item_Identifier               object
# Item_Weight                  float64
# Item_Fat_Content              object
# Item_Visibility              float64
# Item_Type                     object
# Item_MRP                     float64
# Outlet_Identifier             object
# Outlet_Establishment_Year      int64
# Outlet_Size                   object
# Outlet_Location_Type          object
# Outlet_Type                   object
# Item_Outlet_Sales            float64
# dtype: object

# %% [markdown]
# ## Grouping the data

# %%
cont_data = train_data.select_dtypes(include=['int64', 'float64'])
# cont_data = train_data.select_dtypes(exclude = "object")

cat_data = train_data.select_dtypes(include = "object")
# catt_data = train_data.select_dtypes(exclude=['int64', 'float64'])

# %%
cont_data.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0         9.30         0.016047  249.8092                       1999
# 1         5.92         0.019278   48.2692                       2009
# 2        17.50         0.016760  141.6180                       1999
# 3        19.20         0.000000  182.0950                       1998
# 4         8.93         0.000000   53.8614                       1987
#
#    Item_Outlet_Sales
# 0          3735.1380
# 1           443.4228
# 2          2097.2700
# 3           732.3800
# 4                NaN

# %%
cat_data.head()
# Out:
#   Item_Identifier Item_Fat_Content              Item_Type Outlet_Identifier  \
# 0           FDA15          Low Fat                  Dairy            OUT049
# 1           DRC01          Regular            Soft Drinks            OUT018
# 2           FDN15          Low Fat                   Meat            OUT049
# 3           FDX07          Regular  Fruits and Vegetables            OUT010
# 4           NCD19          Low Fat              Household            OUT013
#
#   Outlet_Size Outlet_Location_Type        Outlet_Type
# 0      Medium               Tier 1  Supermarket Type1
# 1      Medium               Tier 3  Supermarket Type2
# 2      Medium               Tier 1  Supermarket Type1
# 3         NaN               Tier 3      Grocery Store
# 4        High               Tier 3  Supermarket Type1

# %% [markdown]
# ### Imputing for the missing values
# #### Cont data
# - Visualize distributions

# %%
cont_data.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
plt.figure(figsize=(20, 20))
for i, col in enumerate(cont_data.columns):
    plt.subplot(3,2, i+1)
    plt.hist(train_data[col])
    plt.title(col)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
cont_data.isnull().sum()
# Out:
# Item_Weight                  1463
# Item_Visibility                 0
# Item_MRP                        0
# Outlet_Establishment_Year       0
# Item_Outlet_Sales               5
# dtype: int64

# %% [markdown]
# - IMPUTING FOR THIS DATA

# %%
train_data["Item_Weight"] = train_data["Item_Weight"].fillna(train_data["Item_Weight"].median())
train_data["Item_Outlet_Sales"] = train_data["Item_Outlet_Sales"].fillna(train_data["Item_Outlet_Sales"].median())

# %%
train_data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
train_data["Outlet_Size"] = train_data["Outlet_Size"].fillna(train_data["Outlet_Size"].mode()[0])
train_data["Outlet_Identifier"] = train_data["Outlet_Identifier"].fillna(train_data["Outlet_Identifier"].mode()[0])

# %% [markdown]
# ## Outliers

# %%
plt.figure(figsize=(20, 20))
for i, col in enumerate(cont_data.columns):
    plt.subplot(3,2, i+1)
    plt.boxplot(train_data[col])
    plt.title(col)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Let the Outliers using IQR

# %%
import numpy as np
def remove_outliers(columns):
    for col in columns:
        lower_quantile = train_data[col].quantile(0.25)
        upper_quantile = train_data[col].quantile(0.75)

        IQR = upper_quantile-lower_quantile

        upper_boundary =upper_quantile + 1.5 * IQR
        lower_boundary = lower_quantile - 1.5 * IQR

        train_data[col] = np.where(train_data[col]>upper_boundary,upper_boundary, train_data[col])
        train_data[col] = np.where(train_data[col]<lower_boundary,lower_boundary, train_data[col])

# %%
cont_data.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
remove_outliers(['Item_Visibility', 'Item_Outlet_Sales'])

# %%
plt.figure(figsize=(20, 20))
for i, col in enumerate(cont_data.columns):
    plt.subplot(3,2, i+1)
    plt.boxplot(train_data[col])
    plt.title(col)
plt.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ## Other Others for handling Outliers

# %%
data = {
    'values': [10, 12, 14, 15, 16, 17, 18, 19, 20, 25, 30, 100]
}
df = pd.DataFrame(data)
df
# Out:
#     values
# 0       10
# 1       12
# 2       14
# 3       15
# 4       16
# 5       17
# 6       18
# 7       19
# 8       20
# 9       25
# 10      30
# 11     100

# %%
import warnings
warnings.filterwarnings("ignore")
plt.boxplot(df["values"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16881e14530>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16881e14f50>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16881e16000>],
#  'medians': [<matplotlib.lines.Line2D at 0x16881e15430>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16881e15bb0>],
#  'means': []}

# %% [markdown]
# Clipping the data.

# %%
lower_boundary = 12
upper_boundary = 30

df_clipped = df.clip(lower=lower_boundary, upper=upper_boundary)

# %%
plt.boxplot(df_clipped["values"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x168820647d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16882100fb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16882064110>],
#  'medians': [<matplotlib.lines.Line2D at 0x16881cf10a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16881cf2090>],
#  'means': []}

# %% [markdown]
# Z-score

# %%
from scipy import stats

df["z_score"] = stats.zscore(df['values'])
threshold = 2
df
filtered_data = df[np.abs(df['z_score']) <= threshold]
# Out:
#     values   z_score
# 0       10 -0.629278
# 1       12 -0.543468
# 2       14 -0.457657
# 3       15 -0.414752
# 4       16 -0.371846
# 5       17 -0.328941
# 6       18 -0.286036
# 7       19 -0.243130
# 8       20 -0.200225
# 9       25  0.014302
# 10      30  0.228828
# 11     100  3.232201

# %%
plt.boxplot(df["values"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16880c537a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16880c53ce0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16880c53500>],
#  'medians': [<matplotlib.lines.Line2D at 0x16880c782f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16880c785f0>],
#  'means': []}

# %%
plt.boxplot(filtered_data["values"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1688090b890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1688090bdd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1688090b740>],
#  'medians': [<matplotlib.lines.Line2D at 0x16880948410>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16880948710>],
#  'means': []}

# %% [markdown]
# ### Significant Relationships
# - target variable (is what we are predicting) [Dependant]
# - predictors (factors we considers) [independent]
# - ``Hypothesis testing``

# %% [markdown]
# |Data type 1(target)| Data type 2(predictor)| Visualization | Test|
# |:------------|:-----------|:------------|:------|
# |Cont        | Cont        |Scatter plots   | Correlation matrix |
# |Cont       | Cat          | Boxplots       | Anova Test  |
# |Cat        | Cat          | Barpots        | Contigency/ Chi square test|
#
# - Target = ``Item_Outlet_Sale``

# %%
train_data.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# - checking the data type of the target

# %%
train_data["Item_Outlet_Sales"].dtype
# Out:
# dtype('float64')

# %%
cont_data
# Out:
#       Item_Weight  Item_Visibility  Item_MRP  Outlet_Establishment_Year  \
# 0           9.300         0.016047  249.8092                       1999
# 1           5.920         0.019278   48.2692                       2009
# 2          17.500         0.016760  141.6180                       1999
# 3          19.200         0.000000  182.0950                       1998
# 4           8.930         0.000000   53.8614                       1987
# ...           ...              ...       ...                        ...
# 8518        6.865         0.056783  214.5218                       1987
# 8519        8.380         0.046982  108.1570                       2002
# 8520       10.600         0.035186   85.1224                       2004
# 8521        7.210         0.145221  103.1332                       2009
# 8522       14.800         0.044878   75.4670                       1997
#
#       Item_Outlet_Sales
# 0             3735.1380
# 1              443.4228
# 2             2097.2700
# ...

# %% [markdown]
# ### CONT VS CONT
# - correlation matrix

# %%
import seaborn as sns
correlation_matrix = cont_data.corr()
correlation_matrix
plt.figure(figsize=(8,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
# Out:
# <Axes: >

# %% [markdown]
# Visualizing with a scatter plot

# %%
def plot_scatters(cont_data):
    plt.figure(figsize=(10,10))
    for i, col in enumerate(cont_data.columns):
        plt.subplot(2,3, i+1)
        sns.scatterplot(train_data, y = "Item_Outlet_Sales", x = col)
        plt.title(f"Item_Outlet_Sales vs {col}")

    plt.tight_layout()
    plt.show()

# %%
plot_scatters(cont_data)
